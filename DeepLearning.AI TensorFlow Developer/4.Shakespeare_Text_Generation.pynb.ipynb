# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import tensorflow.keras.utils as ku 
import numpy as np

# %%
tokenizer = Tokenizer()
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sonnets.txt \
    -O /tmp/sonnets.txt
data = open('/tmp/sonnets.txt').read()

corpus = data.lower().split("\n")


tokenizer.fit_on_texts(corpus)
total_words = len(tokenizer.word_index) + 1

# create input sequences using list of tokens
input_sequences = []
for line in corpus:
	token_list = tokenizer.texts_to_sequences([line])[0]
	for i in range(1, len(token_list)):
		n_gram_sequence = token_list[:i+1]
		input_sequences.append(n_gram_sequence)


# pad sequences 
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# create predictors and label
predictors, label = input_sequences[:,:-1],input_sequences[:,-1]

label = ku.to_categorical(label, num_classes=total_words)
# Out:
# --2021-01-07 07:48:28--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sonnets.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.62.128, 172.253.122.128, 172.253.115.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.62.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 93578 (91K) [text/plain]
# Saving to: ‘/tmp/sonnets.txt’
#
# /tmp/sonnets.txt    100%[===================>]  91.38K  --.-KB/s    in 0.001s
#
# 2021-01-07 07:48:28 (138 MB/s) - ‘/tmp/sonnets.txt’ saved [93578/93578]

# %%
model = Sequential()
model.add(Embedding(total_words, 100, input_length=max_sequence_len-1))
model.add(Bidirectional(LSTM(150, return_sequences = True)))
model.add(Dropout(0.2))
model.add(LSTM(100))
model.add(Dense(total_words/2, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(total_words, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 10, 100)           321100
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 10, 300)           301200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 300)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 100)               160400
# _________________________________________________________________
# dense_2 (Dense)              (None, 1605)              162105
# _________________________________________________________________
# dense_3 (Dense)              (None, 3211)              5156866
# =================================================================
# Total params: 6,101,671
# Trainable params: 6,101,671
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
 history = model.fit(predictors, label, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 484/484 [==============================] - 9s 11ms/step - loss: 7.3464 - accuracy: 0.0174
# Epoch 2/100
# 484/484 [==============================] - 6s 12ms/step - loss: 6.4874 - accuracy: 0.0231
# Epoch 3/100
# 484/484 [==============================] - 6s 11ms/step - loss: 6.3991 - accuracy: 0.0231
# Epoch 4/100
# 484/484 [==============================] - 6s 11ms/step - loss: 6.2867 - accuracy: 0.0266
# Epoch 5/100
# 484/484 [==============================] - 6s 11ms/step - loss: 6.1485 - accuracy: 0.0361
# Epoch 6/100
# 484/484 [==============================] - 5s 11ms/step - loss: 6.1003 - accuracy: 0.0391
# Epoch 7/100
# 484/484 [==============================] - 5s 11ms/step - loss: 6.0002 - accuracy: 0.0405
# Epoch 8/100
# 484/484 [==============================] - 6s 11ms/step - loss: 5.9338 - accuracy: 0.0428
# Epoch 9/100
# 484/484 [==============================] - 6s 12ms/step - loss: 5.8429 - accuracy: 0.0464
# Epoch 10/100
# 484/484 [==============================] - 5s 11ms/step - loss: 5.7305 - accuracy: 0.0556
# Epoch 11/100
# 484/484 [==============================] - 5s 11ms/step - loss: 5.6446 - accuracy: 0.0595
# Epoch 12/100
# 484/484 [==============================] - 6s 12ms/step - loss: 5.5232 - accuracy: 0.0634
# Epoch 13/100
# 484/484 [==============================] - 5s 11ms/step - loss: 5.4444 - accuracy: 0.0718
# Epoch 14/100
# 484/484 [==============================] - 5s 11ms/step - loss: 5.3222 - accuracy: 0.0761
# Epoch 15/100
# 484/484 [==============================] - 5s 11ms/step - loss: 5.2053 - accuracy: 0.0859
# Epoch 16/100
# 484/484 [==============================] - 5s 11ms/step - loss: 5.0827 - accuracy: 0.0980
# Epoch 17/100
# 484/484 [==============================] - 5s 11ms/step - loss: 5.0011 - accuracy: 0.1021
# Epoch 18/100
# 484/484 [==============================] - 5s 11ms/step - loss: 4.8708 - accuracy: 0.1140
# Epoch 19/100
# 484/484 [==============================] - 6s 12ms/step - loss: 4.7663 - accuracy: 0.1233
# Epoch 20/100
# 484/484 [==============================] - 5s 11ms/step - loss: 4.6692 - accuracy: 0.1340
# Epoch 21/100
# 484/484 [==============================] - 5s 11ms/step - loss: 4.5679 - accuracy: 0.1427
# Epoch 22/100
# 484/484 [==============================] - 5s 11ms/step - loss: 4.4665 - accuracy: 0.1479
# Epoch 23/100
# 484/484 [==============================] - 5s 11ms/step - loss: 4.3615 - accuracy: 0.1664
# Epoch 24/100
# 484/484 [==============================] - 6s 11ms/step - loss: 4.2496 - accuracy: 0.1819
# Epoch 25/100
# 484/484 [==============================] - 5s 11ms/step - loss: 4.1301 - accuracy: 0.1914
# Epoch 26/100
# 484/484 [==============================] - 6s 12ms/step - loss: 4.0309 - accuracy: 0.2100
# Epoch 27/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.9289 - accuracy: 0.2182
# Epoch 28/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.8182 - accuracy: 0.2434
# Epoch 29/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.6972 - accuracy: 0.2616
# Epoch 30/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.6218 - accuracy: 0.2762
# Epoch 31/100
# 484/484 [==============================] - 6s 11ms/step - loss: 3.4896 - accuracy: 0.3057
# Epoch 32/100
# 484/484 [==============================] - 6s 11ms/step - loss: 3.4106 - accuracy: 0.3128
# Epoch 33/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.3215 - accuracy: 0.3467
# Epoch 34/100
# 484/484 [==============================] - 6s 11ms/step - loss: 3.2392 - accuracy: 0.3651
# Epoch 35/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.1863 - accuracy: 0.3798
# Epoch 36/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.0508 - accuracy: 0.4077
# Epoch 37/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.9891 - accuracy: 0.4226
# Epoch 38/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.9088 - accuracy: 0.4380
# Epoch 39/100
# 484/484 [==============================] - 5s 11ms/step - loss: 2.8367 - accuracy: 0.4521
# Epoch 40/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.7958 - accuracy: 0.4583
# Epoch 41/100
# 484/484 [==============================] - 5s 11ms/step - loss: 2.6877 - accuracy: 0.4867
# Epoch 42/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.6390 - accuracy: 0.4945
# Epoch 43/100
# 484/484 [==============================] - 5s 11ms/step - loss: 2.5757 - accuracy: 0.5115
# Epoch 44/100
# 484/484 [==============================] - 5s 11ms/step - loss: 2.4968 - accuracy: 0.5317
# Epoch 45/100
# 484/484 [==============================] - 5s 11ms/step - loss: 2.4334 - accuracy: 0.5472
# Epoch 46/100
# 484/484 [==============================] - 5s 11ms/step - loss: 2.3868 - accuracy: 0.5554
# Epoch 47/100
# 484/484 [==============================] - 5s 11ms/step - loss: 2.3674 - accuracy: 0.5590
# Epoch 48/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.3010 - accuracy: 0.5780
# Epoch 49/100
# 484/484 [==============================] - 5s 11ms/step - loss: 2.2316 - accuracy: 0.5919
# Epoch 50/100
# 484/484 [==============================] - 5s 11ms/step - loss: 2.2023 - accuracy: 0.5958
# Epoch 51/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.1485 - accuracy: 0.6085
# Epoch 52/100
# 484/484 [==============================] - 5s 11ms/step - loss: 2.1150 - accuracy: 0.6182
# Epoch 53/100
# 484/484 [==============================] - 5s 11ms/step - loss: 2.0661 - accuracy: 0.6247
# Epoch 54/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.0018 - accuracy: 0.6449
# Epoch 55/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.9716 - accuracy: 0.6476
# Epoch 56/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.9524 - accuracy: 0.6502
# Epoch 57/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.9287 - accuracy: 0.6533
# Epoch 58/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.8678 - accuracy: 0.6704
# Epoch 59/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.8308 - accuracy: 0.6770
# Epoch 60/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.8281 - accuracy: 0.6788
# Epoch 61/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.7811 - accuracy: 0.6865
# Epoch 62/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.7848 - accuracy: 0.6779
# Epoch 63/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.7179 - accuracy: 0.7005
# Epoch 64/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.6669 - accuracy: 0.7124
# Epoch 65/100
# 484/484 [==============================] - 6s 11ms/step - loss: 1.6308 - accuracy: 0.7200
# Epoch 66/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.6388 - accuracy: 0.7165
# Epoch 67/100
# 484/484 [==============================] - 6s 11ms/step - loss: 1.6126 - accuracy: 0.7223
# Epoch 68/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.5912 - accuracy: 0.7262
# Epoch 69/100
# 484/484 [==============================] - 6s 11ms/step - loss: 1.5647 - accuracy: 0.7286
# Epoch 70/100
# 484/484 [==============================] - 6s 11ms/step - loss: 1.5395 - accuracy: 0.7367
# Epoch 71/100
# 484/484 [==============================] - 6s 11ms/step - loss: 1.5193 - accuracy: 0.7390
# Epoch 72/100
# 484/484 [==============================] - 6s 11ms/step - loss: 1.5059 - accuracy: 0.7395
# Epoch 73/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.4770 - accuracy: 0.7467
# Epoch 74/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.4530 - accuracy: 0.7561
# Epoch 75/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.4378 - accuracy: 0.7571
# Epoch 76/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.4212 - accuracy: 0.7545
# Epoch 77/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.4067 - accuracy: 0.7612
# Epoch 78/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.3667 - accuracy: 0.7708
# Epoch 79/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.3725 - accuracy: 0.7644
# Epoch 80/100
# 484/484 [==============================] - 6s 11ms/step - loss: 1.3317 - accuracy: 0.7735
# Epoch 81/100
# 484/484 [==============================] - 6s 11ms/step - loss: 1.3433 - accuracy: 0.7694
# Epoch 82/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.3110 - accuracy: 0.7772
# Epoch 83/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.3110 - accuracy: 0.7746
# Epoch 84/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.3014 - accuracy: 0.7784
# Epoch 85/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.2752 - accuracy: 0.7833
# Epoch 86/100
# 484/484 [==============================] - 6s 11ms/step - loss: 1.2439 - accuracy: 0.7910
# Epoch 87/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.2359 - accuracy: 0.7905
# Epoch 88/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.2439 - accuracy: 0.7884
# Epoch 89/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.2422 - accuracy: 0.7891
# Epoch 90/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.2038 - accuracy: 0.7927
# Epoch 91/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.2018 - accuracy: 0.7959
# Epoch 92/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.2085 - accuracy: 0.7957
# Epoch 93/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.1869 - accuracy: 0.7970
# Epoch 94/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.1733 - accuracy: 0.7989
# Epoch 95/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.1579 - accuracy: 0.8044
# Epoch 96/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.1351 - accuracy: 0.8062
# Epoch 97/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.1196 - accuracy: 0.8106
# Epoch 98/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.1237 - accuracy: 0.8104
# Epoch 99/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.1253 - accuracy: 0.8081
# Epoch 100/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.1053 - accuracy: 0.8111

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
loss = history.history['loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.title('Training accuracy')

plt.figure()

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.title('Training loss')
plt.legend()

plt.show()

# %%
seed_text = "Help me Obi Wan Kenobi, you're my only hope"
next_words = 100
  
for _ in range(next_words):
	token_list = tokenizer.texts_to_sequences([seed_text])[0]
	token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
	predicted = model.predict_classes(token_list, verbose=0)
	output_word = ""
	for word, index in tokenizer.word_index.items():
		if index == predicted:
			output_word = word
			break
	seed_text += " " + output_word
print(seed_text)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Help me Obi Wan Kenobi, you're my only hope new so made can give none flow go and kind still alone doth stay ill 'no new ' remains live alone alone doth say his woe kind shall loved be now now be praise room grow laws forth live good gone well lies men ' can still live ' forgotten find respect increase ruining alone now proved him new bright true wretched scope alone alone alone thou find mine hadst muse find so woe did grow grow forth dead miss'd near flow speak well live by great rolling ruining wretched scope alone alone are none shine bright forsworn forth men
